# %% [markdown]
# # 🤖 Natural Images Recogniser
#
# We are going to develop a neural network that classifies various types of images. To do so, we are going to use a dataset contained in our Google Drive account. This dataset is made up of 8 different classes, where each of these classes contains 560 images that will be used during the training process. Similarly, these same classes are available to be used in the validation phase, each of these classes containing 140 different images.

# %%
# Mounts the Google Drive directory in which the dataset is hosted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Am I really using a GPU? Check in **Edit / Notebook Settings** or **Runtime / Change runtime type**.

# %%
# Check that we are making use of a GPU for training the neural network
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# Let's see an example image.

# %%
# List the directories available in the dataset to know the organisation of the data
# !ls "/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/"

# An example image is displayed, which will be used during the training phase of the network to determine the size of the image
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Training/cat/cat_0250.jpg', 'r')
imshow(np.asarray(pil_im))
# Out:
# Training  Validation

# %% [markdown]
# ## First Model

# %%
# Data source

image_size = (100, 100) # Images of 100x100 dimension
batch_size = 64         # Number of images that are passed to the network per epoch

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Training",
    validation_split=0.2,     # 20% of images for validation
    subset="training",
    seed=1337,                # In an iteration, we do not feed the network with all the images but with small portions given by the batch_size
    image_size=image_size,    # Size of our dataset images
    batch_size=batch_size, 
    label_mode='categorical'  # The network classifies more than two classes (categorical), if the network would classify two classes (binary)
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Validation",
    validation_split=0.2,     # 80% of images for training
    subset="validation",
    seed=1337,                # This is a specific way of randomising the data used during the training phase of the network
    image_size=image_size,    # Recommended images sizes (100, 200, 512)
    batch_size=batch_size,
    label_mode='categorical' 
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# Out:
# Found 4480 files belonging to 8 classes.
# Using 3584 files for training.
# Found 1120 files belonging to 8 classes.
# Using 224 files for validation.

# %%
# Convolutional Neural Network Model

import tensorflow as tf
from tensorflow import keras        
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten
from tensorflow.keras.callbacks import EarlyStopping

model = keras.Sequential()            # Model initialisation mode. Sequential mode adds one layer after another
model.add(Rescaling(scale=(1./127.5), # Layer for the normalisation of the dataset image set
                    offset=-1,
                    input_shape=(100, 100, 3)))               # Size of the input images

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))  # First convolutional layer. Fully connected layer
model.add(MaxPooling2D(pool_size=(2, 2)))                     # Halves the image (in our case, the image would be 49x49)

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))  # kernel_size = image filter
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))  # Deactivates 25% of the neurons, forcing the network to rely on the remaining neurons available for training

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))  # Causes it to stop using the same neurons during the learning phase (switches them off in the previous layer)

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.7))

model.add(Flatten())                      # Converts the matrix into a vector
model.add(Dense(128, activation='relu'))  # Simplification of the vector obtained above
model.add(Dropout(0.5))

model.add(Dense(8, activation='softmax')) # The first parameter specifies the number of classes the dataset has

# Specify the model compilation mode
model.compile(loss=tf.keras.losses.categorical_crossentropy,  # Loss function
              optimizer=tf.keras.optimizers.Adam(1e-3),       # Adam optimiser (based on SGD = Stochastic Gradient Descent)
              metrics=['accuracy'])                           # Metric that measures the learning accuracy of the network in each epoch

# %%
# Training Phase

epochs = 200

# Once the highest value is reached in the network and it stabilises or starts
# to have losses, the training process is stopped. The parameter patience=10 makes
# it stop after 10 waiting epochs when the highest value has been recorded and the
# model has not improved, so that finally we will have the best value and therefore
# the best weights.
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10, restore_best_weights=True)

# The model fits the given training and validation data, the number of epochs and each of the previously implemented layers
h = model.fit(
        train_ds,
        epochs=epochs, 
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/200
# 56/56 [==============================] - 11s 150ms/step - loss: 1.9483 - accuracy: 0.2023 - val_loss: 1.8108 - val_accuracy: 0.2991
# Epoch 2/200
# 56/56 [==============================] - 9s 145ms/step - loss: 1.6104 - accuracy: 0.3491 - val_loss: 1.4348 - val_accuracy: 0.5045
# Epoch 3/200
# 56/56 [==============================] - 9s 140ms/step - loss: 1.2320 - accuracy: 0.5460 - val_loss: 1.2786 - val_accuracy: 0.4866
# Epoch 4/200
# 56/56 [==============================] - 9s 148ms/step - loss: 1.0253 - accuracy: 0.6295 - val_loss: 1.0931 - val_accuracy: 0.6562
# Epoch 5/200
# 56/56 [==============================] - 9s 141ms/step - loss: 0.8970 - accuracy: 0.6766 - val_loss: 0.8096 - val_accuracy: 0.6964
# Epoch 6/200
# 56/56 [==============================] - 9s 141ms/step - loss: 0.7662 - accuracy: 0.7288 - val_loss: 0.8827 - val_accuracy: 0.6920
# Epoch 7/200
# 56/56 [==============================] - 9s 146ms/step - loss: 0.6887 - accuracy: 0.7500 - val_loss: 0.6672 - val_accuracy: 0.7232
# Epoch 8/200
# 56/56 [==============================] - 9s 142ms/step - loss: 0.6459 - accuracy: 0.7623 - val_loss: 0.6349 - val_accuracy: 0.7455
# Epoch 9/200
# 56/56 [==============================] - 9s 143ms/step - loss: 0.5473 - accuracy: 0.7846 - val_loss: 0.5249 - val_accuracy: 0.7857
# Epoch 10/200
# 56/56 [==============================] - 9s 142ms/step - loss: 0.5378 - accuracy: 0.8002 - val_loss: 0.6406 - val_accuracy: 0.7366
# Epoch 11/200
# 56/56 [==============================] - 9s 147ms/step - loss: 0.5084 - accuracy: 0.8119 - val_loss: 0.5363 - val_accuracy: 0.8170
# Epoch 12/200
# 56/56 [==============================] - 9s 147ms/step - loss: 0.4153 - accuracy: 0.8449 - val_loss: 0.4347 - val_accuracy: 0.8616
# Epoch 13/200
# 56/56 [==============================] - 9s 144ms/step - loss: 0.4372 - accuracy: 0.8368 - val_loss: 0.5384 - val_accuracy: 0.8214
# Epoch 14/200
# 56/56 [==============================] - 9s 143ms/step - loss: 0.4281 - accuracy: 0.8429 - val_loss: 0.5058 - val_accuracy: 0.8036
# Epoch 15/200
# 56/56 [==============================] - 9s 148ms/step - loss: 0.3578 - accuracy: 0.8652 - val_loss: 0.5165 - val_accuracy: 0.8304
# Epoch 16/200
# 56/56 [==============================] - 9s 147ms/step - loss: 0.3825 - accuracy: 0.8616 - val_loss: 0.4793 - val_accuracy: 0.8170
# Epoch 17/200
# 56/56 [==============================] - 9s 148ms/step - loss: 0.3504 - accuracy: 0.8694 - val_loss: 0.4755 - val_accuracy: 0.8616
# Epoch 18/200
# 56/56 [==============================] - 9s 144ms/step - loss: 0.3264 - accuracy: 0.8797 - val_loss: 0.3937 - val_accuracy: 0.8304
# Epoch 19/200
# 56/56 [==============================] - 9s 146ms/step - loss: 0.2940 - accuracy: 0.8903 - val_loss: 0.4418 - val_accuracy: 0.8438
# Epoch 20/200
# 56/56 [==============================] - 9s 145ms/step - loss: 0.3065 - accuracy: 0.8823 - val_loss: 0.4530 - val_accuracy: 0.8571
# Epoch 21/200
# 56/56 [==============================] - 9s 142ms/step - loss: 0.2847 - accuracy: 0.8965 - val_loss: 0.3829 - val_accuracy: 0.8393
# Epoch 22/200
# 56/56 [==============================] - 9s 146ms/step - loss: 0.2686 - accuracy: 0.9026 - val_loss: 0.3845 - val_accuracy: 0.8795
# Epoch 23/200
# 56/56 [==============================] - 9s 144ms/step - loss: 0.2613 - accuracy: 0.9040 - val_loss: 0.3559 - val_accuracy: 0.9018
# Epoch 24/200
# 56/56 [==============================] - 9s 144ms/step - loss: 0.2514 - accuracy: 0.9127 - val_loss: 0.3702 - val_accuracy: 0.8616
# Epoch 25/200
# 56/56 [==============================] - 9s 144ms/step - loss: 0.2279 - accuracy: 0.9196 - val_loss: 0.4423 - val_accuracy: 0.8795
# Epoch 26/200
# 56/56 [==============================] - 9s 145ms/step - loss: 0.2179 - accuracy: 0.9261 - val_loss: 0.3315 - val_accuracy: 0.9062
# Epoch 27/200
# 56/56 [==============================] - 9s 145ms/step - loss: 0.2283 - accuracy: 0.9135 - val_loss: 0.3322 - val_accuracy: 0.8929
# Epoch 28/200
# 56/56 [==============================] - 9s 145ms/step - loss: 0.2222 - accuracy: 0.9199 - val_loss: 0.4076 - val_accuracy: 0.8616
# Epoch 29/200
# 56/56 [==============================] - 9s 147ms/step - loss: 0.2070 - accuracy: 0.9247 - val_loss: 0.4132 - val_accuracy: 0.8438
# Epoch 30/200
# 56/56 [==============================] - 9s 143ms/step - loss: 0.2628 - accuracy: 0.9135 - val_loss: 0.4610 - val_accuracy: 0.8482
# Epoch 31/200
# 56/56 [==============================] - 9s 146ms/step - loss: 0.1815 - accuracy: 0.9305 - val_loss: 0.3578 - val_accuracy: 0.8884
# Epoch 32/200
# 56/56 [==============================] - 9s 151ms/step - loss: 0.1956 - accuracy: 0.9308 - val_loss: 0.3434 - val_accuracy: 0.9018
# Epoch 33/200
# 56/56 [==============================] - 9s 142ms/step - loss: 0.1974 - accuracy: 0.9325 - val_loss: 0.3677 - val_accuracy: 0.8929
# Epoch 34/200
# 56/56 [==============================] - 9s 145ms/step - loss: 0.1733 - accuracy: 0.9339 - val_loss: 0.2625 - val_accuracy: 0.9286
# Epoch 35/200
# 56/56 [==============================] - 9s 140ms/step - loss: 0.1686 - accuracy: 0.9406 - val_loss: 0.2982 - val_accuracy: 0.9107
# Epoch 36/200
# 56/56 [==============================] - 9s 147ms/step - loss: 0.1775 - accuracy: 0.9408 - val_loss: 0.4197 - val_accuracy: 0.8839
# Epoch 37/200
# 56/56 [==============================] - 9s 148ms/step - loss: 0.1716 - accuracy: 0.9406 - val_loss: 0.3365 - val_accuracy: 0.8973
# Epoch 38/200
# 56/56 [==============================] - 9s 142ms/step - loss: 0.1424 - accuracy: 0.9484 - val_loss: 0.4601 - val_accuracy: 0.8884
# Epoch 39/200
# 56/56 [==============================] - 9s 147ms/step - loss: 0.1739 - accuracy: 0.9397 - val_loss: 0.3004 - val_accuracy: 0.9062
# Epoch 40/200
# 56/56 [==============================] - 9s 145ms/step - loss: 0.1244 - accuracy: 0.9542 - val_loss: 0.3935 - val_accuracy: 0.9018
# Epoch 41/200
# 56/56 [==============================] - 9s 146ms/step - loss: 0.1406 - accuracy: 0.9515 - val_loss: 0.2696 - val_accuracy: 0.9330
# Epoch 42/200
# 56/56 [==============================] - 9s 135ms/step - loss: 0.1463 - accuracy: 0.9498 - val_loss: 0.2775 - val_accuracy: 0.9330
# Epoch 43/200
# 56/56 [==============================] - 9s 137ms/step - loss: 0.1163 - accuracy: 0.9568 - val_loss: 0.3426 - val_accuracy: 0.9062
# Epoch 44/200
# 56/56 [==============================] - 9s 142ms/step - loss: 0.1147 - accuracy: 0.9612 - val_loss: 0.2523 - val_accuracy: 0.9375
# Epoch 45/200
# 56/56 [==============================] - 9s 135ms/step - loss: 0.1193 - accuracy: 0.9568 - val_loss: 0.2800 - val_accuracy: 0.9062
# Epoch 46/200
# 56/56 [==============================] - 9s 139ms/step - loss: 0.1284 - accuracy: 0.9573 - val_loss: 0.2658 - val_accuracy: 0.9330
# Epoch 47/200
# 56/56 [==============================] - 9s 137ms/step - loss: 0.0936 - accuracy: 0.9676 - val_loss: 0.3053 - val_accuracy: 0.9286
# Epoch 48/200
# 56/56 [==============================] - 9s 139ms/step - loss: 0.1156 - accuracy: 0.9621 - val_loss: 0.3000 - val_accuracy: 0.9196
# Epoch 49/200
# 56/56 [==============================] - 9s 136ms/step - loss: 0.1633 - accuracy: 0.9540 - val_loss: 0.3390 - val_accuracy: 0.9107
# Epoch 50/200
# 56/56 [==============================] - 9s 135ms/step - loss: 0.1063 - accuracy: 0.9648 - val_loss: 0.3311 - val_accuracy: 0.9152
# Epoch 51/200
# 56/56 [==============================] - 9s 138ms/step - loss: 0.1005 - accuracy: 0.9665 - val_loss: 0.4512 - val_accuracy: 0.8929
# Epoch 52/200
# 56/56 [==============================] - 9s 139ms/step - loss: 0.1228 - accuracy: 0.9615 - val_loss: 0.3498 - val_accuracy: 0.9018
# Epoch 53/200
# 56/56 [==============================] - 9s 141ms/step - loss: 0.1122 - accuracy: 0.9640 - val_loss: 0.2873 - val_accuracy: 0.9196
# Epoch 54/200
# 55/56 [============================>.] - ETA: 0s - loss: 0.1085 - accuracy: 0.9645Restoring model weights from the end of the best epoch: 44.
# 56/56 [==============================] - 9s 144ms/step - loss: 0.1085 - accuracy: 0.9643 - val_loss: 0.2555 - val_accuracy: 0.9196
# Epoch 00054: early stopping

# %%
# Graphical representation of the results obtained during the training phase
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation','loss'], loc='upper right')
plt.show()

# %% [markdown]
# ## Evaluation of the results

# %%
# Confusion matrix. Allow visualisation of neural network performance
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

print(classification_report(labels, predictions, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9167    0.9167    0.9167        24
#            1     0.9459    1.0000    0.9722        35
#            2     0.8519    0.8846    0.8679        26
#            3     0.8438    0.8182    0.8308        33
#            4     0.9677    0.9677    0.9677        31
#            5     1.0000    1.0000    1.0000        25
#            6     1.0000    0.9524    0.9756        21
#            7     1.0000    0.9655    0.9825        29
#
#     accuracy                         0.9375       224
#    macro avg     0.9407    0.9381    0.9392       224
# weighted avg     0.9379    0.9375    0.9374       224

# %%
# Validation Phase

img = keras.preprocessing.image.load_img(
    '/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Validation/dog/dog_0002.jpg', target_size=image_size
)

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)    # Once trained, the network tries to predict to which class the given validation image belongs
print(np.argmax(predictions[0])) 

# The result obtained below represents the classification performed by the
# neural network in this validation process after the training phase.
# From an image belonging to the set of validation images and not used in
# the training process, the network classifies and returns the number of the
# class to which this image belongs.
# Out:
# 3
