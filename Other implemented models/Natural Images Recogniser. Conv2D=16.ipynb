# %% [markdown]
# # 🤖 Natural Images Recogniser
#
# We are going to develop a neural network that classifies various types of images. To do so, we are going to use a dataset contained in our Google Drive account. This dataset is made up of 8 different classes, where each of these classes contains 560 images that will be used during the training process. Similarly, these same classes are available to be used in the validation phase, each of these classes containing 140 different images.

# %%
# Mounts the Google Drive directory in which the dataset is hosted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Am I really using a GPU? Check in **Edit / Notebook Settings** or **Runtime / Change runtime type**.

# %%
# Check that we are making use of a GPU for training the neural network
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# Let's see an example image.

# %%
# List the directories available in the dataset to know the organisation of the data
# !ls "/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/"

# An example image is displayed, which will be used during the training phase of the network to determine the size of the image
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Training/cat/cat_0250.jpg', 'r')
imshow(np.asarray(pil_im))
# Out:
# Training  Validation

# %% [markdown]
# ## First Model

# %%
# Data source

image_size = (100, 100) # Images of 100x100 dimension
batch_size = 32         # Number of images that are passed to the network per epoch

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Training",
    validation_split=0.2,     # 20% of images for validation
    subset="training",
    seed=1337,                # In an iteration, we do not feed the network with all the images but with small portions given by the batch_size
    image_size=image_size,    # Size of our dataset images
    batch_size=batch_size, 
    label_mode='categorical'  # The network classifies more than two classes (categorical), if the network would classify two classes (binary)
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Validation",
    validation_split=0.2,     # 80% of images for training
    subset="validation",
    seed=1337,                # This is a specific way of randomising the data used during the training phase of the network
    image_size=image_size,    # Recommended images sizes (100, 200, 512)
    batch_size=batch_size,
    label_mode='categorical' 
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# Out:
# Found 4480 files belonging to 8 classes.
# Using 3584 files for training.
# Found 1120 files belonging to 8 classes.
# Using 224 files for validation.

# %%
# Convolutional Neural Network Model

import tensorflow as tf
from tensorflow import keras        
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten
from tensorflow.keras.callbacks import EarlyStopping

model = keras.Sequential()            # Model initialisation mode. Sequential mode adds one layer after another
model.add(Rescaling(scale=(1./127.5), # Layer for the normalisation of the dataset image set
                    offset=-1,
                    input_shape=(100, 100, 3)))               # Size of the input images

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.1))

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))  # First convolutional layer. Fully connected layer
model.add(MaxPooling2D(pool_size=(2, 2)))                     # Halves the image (in our case, the image would be 49x49)

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))  # kernel_size = image filter
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))  # Deactivates 25% of the neurons, forcing the network to rely on the remaining neurons available for training

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))  # Causes it to stop using the same neurons during the learning phase (switches them off in the previous layer)

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.7))

model.add(Flatten())                      # Converts the matrix into a vector
model.add(Dense(128, activation='relu'))  # Simplification of the vector obtained above
model.add(Dropout(0.5))

model.add(Dense(8, activation='softmax')) # The first parameter specifies the number of classes the dataset has

# Specify the model compilation mode
model.compile(loss=tf.keras.losses.categorical_crossentropy,  # Loss function
              optimizer=tf.keras.optimizers.Adam(1e-3),       # Adam optimiser (based on SGD = Stochastic Gradient Descent)
              metrics=['accuracy'])                           # Metric that measures the learning accuracy of the network in each epoch

# %%
# Training Phase

epochs = 200

# Once the highest value is reached in the network and it stabilises or starts
# to have losses, the training process is stopped. The parameter patience=10 makes
# it stop after 10 waiting epochs when the highest value has been recorded and the
# model has not improved, so that finally we will have the best value and therefore
# the best weights.
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10, restore_best_weights=True)

# The model fits the given training and validation data, the number of epochs and each of the previously implemented layers
h = model.fit(
        train_ds,
        epochs=epochs, 
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/200
# 112/112 [==============================] - 11s 82ms/step - loss: 1.9862 - accuracy: 0.1872 - val_loss: 1.8064 - val_accuracy: 0.2321
# Epoch 2/200
# 112/112 [==============================] - 10s 81ms/step - loss: 1.5932 - accuracy: 0.3666 - val_loss: 1.4580 - val_accuracy: 0.4330
# Epoch 3/200
# 112/112 [==============================] - 9s 80ms/step - loss: 1.2759 - accuracy: 0.5198 - val_loss: 1.2469 - val_accuracy: 0.5536
# Epoch 4/200
# 112/112 [==============================] - 9s 79ms/step - loss: 1.1002 - accuracy: 0.5951 - val_loss: 1.1152 - val_accuracy: 0.6161
# Epoch 5/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.9126 - accuracy: 0.6688 - val_loss: 0.8409 - val_accuracy: 0.6696
# Epoch 6/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.7846 - accuracy: 0.7188 - val_loss: 0.7855 - val_accuracy: 0.7232
# Epoch 7/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.7003 - accuracy: 0.7408 - val_loss: 0.9090 - val_accuracy: 0.6652
# Epoch 8/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.6227 - accuracy: 0.7818 - val_loss: 0.6814 - val_accuracy: 0.7500
# Epoch 9/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5945 - accuracy: 0.7838 - val_loss: 0.5332 - val_accuracy: 0.7946
# Epoch 10/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.5518 - accuracy: 0.8002 - val_loss: 0.5714 - val_accuracy: 0.7857
# Epoch 11/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.4911 - accuracy: 0.8131 - val_loss: 0.4242 - val_accuracy: 0.8571
# Epoch 12/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.4699 - accuracy: 0.8225 - val_loss: 0.4396 - val_accuracy: 0.8259
# Epoch 13/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.4702 - accuracy: 0.8304 - val_loss: 0.4666 - val_accuracy: 0.8214
# Epoch 14/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.4250 - accuracy: 0.8387 - val_loss: 0.4769 - val_accuracy: 0.8304
# Epoch 15/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.4053 - accuracy: 0.8518 - val_loss: 0.4191 - val_accuracy: 0.8661
# Epoch 16/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.3976 - accuracy: 0.8513 - val_loss: 0.3587 - val_accuracy: 0.8438
# Epoch 17/200
# 112/112 [==============================] - 10s 83ms/step - loss: 0.3921 - accuracy: 0.8594 - val_loss: 0.3746 - val_accuracy: 0.8482
# Epoch 18/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.3485 - accuracy: 0.8630 - val_loss: 0.3658 - val_accuracy: 0.8571
# Epoch 19/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.3590 - accuracy: 0.8636 - val_loss: 0.4215 - val_accuracy: 0.8571
# Epoch 20/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.3749 - accuracy: 0.8655 - val_loss: 0.4764 - val_accuracy: 0.8527
# Epoch 21/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.3451 - accuracy: 0.8775 - val_loss: 0.3545 - val_accuracy: 0.8839
# Epoch 22/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.3028 - accuracy: 0.8906 - val_loss: 0.3305 - val_accuracy: 0.8705
# Epoch 23/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.3367 - accuracy: 0.8792 - val_loss: 0.4500 - val_accuracy: 0.8304
# Epoch 24/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.2854 - accuracy: 0.8917 - val_loss: 0.3083 - val_accuracy: 0.8929
# Epoch 25/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.2899 - accuracy: 0.8945 - val_loss: 0.3288 - val_accuracy: 0.8884
# Epoch 26/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.3259 - accuracy: 0.8929 - val_loss: 0.3634 - val_accuracy: 0.8839
# Epoch 27/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.2661 - accuracy: 0.9021 - val_loss: 0.2850 - val_accuracy: 0.9062
# Epoch 28/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.2224 - accuracy: 0.9160 - val_loss: 0.3311 - val_accuracy: 0.8839
# Epoch 29/200
# 112/112 [==============================] - 10s 83ms/step - loss: 0.2833 - accuracy: 0.9004 - val_loss: 0.3480 - val_accuracy: 0.8795
# Epoch 30/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.2659 - accuracy: 0.9029 - val_loss: 0.3864 - val_accuracy: 0.8839
# Epoch 31/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.2213 - accuracy: 0.9163 - val_loss: 0.3631 - val_accuracy: 0.8795
# Epoch 32/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.2428 - accuracy: 0.9169 - val_loss: 0.3819 - val_accuracy: 0.8705
# Epoch 33/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.2542 - accuracy: 0.9169 - val_loss: 0.3421 - val_accuracy: 0.8705
# Epoch 34/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.2256 - accuracy: 0.9188 - val_loss: 0.3167 - val_accuracy: 0.9062
# Epoch 35/200
# 112/112 [==============================] - 10s 82ms/step - loss: 0.2257 - accuracy: 0.9180 - val_loss: 0.3254 - val_accuracy: 0.8973
# Epoch 36/200
# 112/112 [==============================] - 10s 81ms/step - loss: 0.2216 - accuracy: 0.9188 - val_loss: 0.3654 - val_accuracy: 0.8705
# Epoch 37/200
# 112/112 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9272Restoring model weights from the end of the best epoch: 27.
# 112/112 [==============================] - 10s 81ms/step - loss: 0.1995 - accuracy: 0.9272 - val_loss: 0.3151 - val_accuracy: 0.9018
# Epoch 00037: early stopping

# %%
# Graphical representation of the results obtained during the training phase
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation','loss'], loc='upper right')
plt.show()

# %% [markdown]
# ## Evaluation of the results

# %%
# Confusion matrix. Allow visualisation of neural network performance
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

print(classification_report(labels, predictions, digits = 4))
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc467a6b830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#               precision    recall  f1-score   support
#
#            0     0.8750    0.9545    0.9130        22
#            1     0.9459    0.8974    0.9211        39
#            2     0.8519    0.7667    0.8070        30
#            3     0.6875    0.8462    0.7586        26
#            4     1.0000    1.0000    1.0000        31
#            5     1.0000    0.9615    0.9804        26
#            6     1.0000    0.9091    0.9524        22
#            7     0.9286    0.9286    0.9286        28
#
#     accuracy                         0.9062       224
#    macro avg     0.9111    0.9080    0.9076       224
# weighted avg     0.9133    0.9062    0.9080       224

# %%
# Validation Phase

img = keras.preprocessing.image.load_img(
    '/content/drive/My Drive/Colab Notebooks/datasets/NaturalDataset/Validation/dog/dog_0002.jpg', target_size=image_size
)

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)    # Once trained, the network tries to predict to which class the given validation image belongs
print(np.argmax(predictions[0])) 

# The result obtained below represents the classification performed by the
# neural network in this validation process after the training phase.
# From an image belonging to the set of validation images and not used in
# the training process, the network classifies and returns the number of the
# class to which this image belongs.
# Out:
# 3
